# %% [markdown]
# # Reproduction of Nagatani (2006) — Chaos in shuttle buses
#
# This notebook reruns every figure of the paper end-to-end. It is a
# thin wrapper around the `experiments/` scripts so reviewers can verify
# the work without leaving the browser.

# %%
# %matplotlib inline
import sys, pathlib
sys.path.insert(0, str(pathlib.Path('..').resolve() / 'src'))
from experiments import (fig2_time_headway, fig3_zoom, fig4_tour_time,
                         fig5_zoom, fig6_return_map, fig7_mean_rms,
                         fig8_phase_diagram)

# %% [markdown]
# ## Fig. 2 — Time headway $H_1(m)$ vs loading parameter $G$

# %%
fig2_time_headway.run()

# %% [markdown]
# ## Fig. 3 — Zoom of Fig. 2

# %%
fig3_zoom

# %% [markdown]
# ## Fig. 4 — Tour times

# %%
fig4_tour_time.run()

# %% [markdown]
# ## Fig. 6 — Return map

# %%
fig6_return_map.run()

# %% [markdown]
# ## Fig. 7 — Means and RMS values

# %%
fig7_mean_rms.run()

# %% [markdown]
# ## Fig. 8 — Phase diagram (this cell can take a couple of minutes)

# %%
fig8_phase_diagram.run()
